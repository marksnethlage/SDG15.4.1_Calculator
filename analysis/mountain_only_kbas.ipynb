# %%
## The purpose of this script is to create a layer that is only mountainous KBAs
## No need to deal with transboundary, because KBAs are split by country
## Using this together with the R Script to calculate overlap will result in mountain-only regions 
## (but not by mountain range)

## import libraries
# %matplotlib inline

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import descartes
from shapely.geometry import Polygon
import geopandas as gpd
import os.path
from PIL import Image
import rasterio

# %%
## global variables
os.chdir("/Users/aminaly/Box Sync/mountain_biodiversity")
CLIP = False

## read in files 
if(CLIP): 
    kba = gpd.read_file(os.getcwd() + "/data/KBA/KBA2020/KBAsGlobal_2020_September_02_POL.shp")
    gmba = gpd.read_file(os.getcwd() + "/data/GMBA/GMBA_Inventory_V2_210420_GME/GMBA_Inventory_V2_210420_GME.shp")
else:
    kba = gpd.read_file(os.getcwd() + "/data/KBA/KBA2020/clipped_KBAsGlobal_2020_September_02_POL.shp")
    gmba = gpd.read_file(os.getcwd() + "/data/GMBA/GMBA_Inventory_V2_210420_GME/clipped_GMBA_Inventory_V2_210420_GME.shp")

# %%
## subset gmba to the level you care about UPDATE THIS
gmba.head()
# Out:
#    GMBA_V2_ID  OID_  GMBA_V2__1 GMBA_V1_ID               RangeNameM  \
# 0       12154     0       12154       None                   Africa
# 1       12155   824       12155       None                  Eurasia
# 2       14264   733       14264       None           Atlantic Ocean
# 3       12157  1724       12157       None                   Europe
# 4       13946   325       13946       None  North African Highlands
#
#                 Ranges_Ran     MapUnit                              Path  \
# 0                   Africa  Aggregated                            Africa
# 1                  Eurasia  Aggregated                           Eurasia
# 2           Atlantic Ocean  Aggregated                    Atlantic Ocean
# 3                   Europe  Aggregated                  Eurasia > Europe
# 4  North African Highlands  Aggregated  Africa > North African Highlands
#
#           Level_1                  Level_2  ... Level_4 Level_5 Level_6  \
# 0          Africa                     None  ...    None    None    None
# 1         Eurasia                     None  ...    None    None    None
# 2  Atlantic Ocean                     None  ...    None    None    None
# 3         Eurasia                   Europe  ...    None    None    None
# 4          Africa  North African Highlands  ...    None    None    None
#
#   Level_7 Level_8 Level_9 Level_10 OBJECTID  CNTRY_NAME  \
# 0    None    None    None     None      206       Spain
# 1    None    None    None     None      206       Spain
# 2    None    None    None     None      206       Spain
# 3    None    None    None     None      206       Spain
# 4    None    None    None     None      206       Spain
#
#                                             geometry
# 0  MULTIPOLYGON (((-2.91472 35.27361, -2.93924 35...
# 1  MULTIPOLYGON (((3.17995 39.32903, 3.12709 39.3...
# 2  MULTIPOLYGON (((-13.77306 28.83778, -13.81944 ...
# 3  MULTIPOLYGON (((3.36905 39.54778, 3.36251 39.5...
# 4  MULTIPOLYGON (((-2.91472 35.27361, -2.93924 35...
#
# [5 rows x 21 columns]
